# %%
import os
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from torchvision.models import resnet18, ResNet18_Weights
from torch.utils.data import Dataset
import glob
import matplotlib.pyplot as plt
import numpy as np
import scipy
import mne

# %%
data = r"/Users/josephthi/Desktop/UCI_Classes/cs184A/CS_184A_Final Project/data/spectrogram_data"

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %%
def append_data(path):
    X_data = []
    y_data = []
    for data in sorted(os.listdir(path)):
        file_path = os.path.join(path, data)
        if 'X' in data:
            X = np.load(file_path)
            X_data.append(X)
        elif 'y' in data:
            y = np.load(file_path)
            y_data.append(y)
        
    return X_data, y_data

# %%
X_data, y_data = append_data(r"data/spectrogram_data")
# X_data_n, y_data_n = append_data(r"data/noisy_spectrogram_data") 

# --- Subject-level split (avoids data leakage) ---
# Each element of X_data/y_data corresponds to one subject
subject_ids = np.arange(len(X_data))
subject_labels = np.array([y[0] for y in y_data])  # get label from first epoch of each subject

# First split: train vs temp
train_ids, temp_ids = train_test_split(
    subject_ids,
    test_size=0.30,
    stratify=subject_labels,   # stratify by subject label
    random_state=42
)

# Second split: val vs test (50/50 of the temp set)
val_ids, test_ids = train_test_split(
    temp_ids,
    test_size=0.50,
    stratify=subject_labels[temp_ids],
    random_state=42
)

print(f"Subject-level split:")
print(f"  Train: {len(train_ids)} subjects")
print(f"  Val:   {len(val_ids)} subjects")
print(f"  Test:  {len(test_ids)} subjects")

# Concatenate all epochs for each split
X_train = np.concatenate([X_data[i] for i in train_ids], axis=0)
y_train = np.concatenate([y_data[i] for i in train_ids], axis=0)

X_val = np.concatenate([X_data[i] for i in val_ids], axis=0)
y_val = np.concatenate([y_data[i] for i in val_ids], axis=0)

X_test = np.concatenate([X_data[i] for i in test_ids], axis=0)
y_test = np.concatenate([y_data[i] for i in test_ids], axis=0)

print(f"Epoch counts after concatenation:")
print(f"  Train: {len(X_train)} epochs")
print(f"  Val:   {len(X_val)} epochs")
print(f"  Test:  {len(X_test)} epochs")
# Out:
# Subject-level split:
#   Train: 61 subjects
#   Val:   13 subjects
#   Test:  14 subjects
# Epoch counts after concatenation:
#   Train: 47064 epochs
#   Val:   10511 epochs
#   Test:  12130 epochs
# Epoch counts after concatenation:
#   Train: 47064 epochs
#   Val:   10511 epochs
#   Test:  12130 epochs

# %%
class EEGDataset(Dataset):
    def __init__(self, X, y):
        super(EEGDataset, self).__init__()
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# --- Per-sample normalization (normalize each epoch independently) ---
# This normalizes each sample to zero-mean, unit-variance across all channels/freq/time
eps = 1e-8

for i in range(X_train.shape[0]):
    m = X_train[i].mean()
    s = X_train[i].std()
    X_train[i] = (X_train[i] - m) / (s + eps)

for i in range(X_val.shape[0]):
    m = X_val[i].mean()
    s = X_val[i].std()
    X_val[i] = (X_val[i] - m) / (s + eps)

for i in range(X_test.shape[0]):
    m = X_test[i].mean()
    s = X_test[i].std()
    X_test[i] = (X_test[i] - m) / (s + eps)

print(f"\nPer-sample normalization complete")
print(f"  Train X: mean={X_train.mean():.3e}, std={X_train.std():.3e}")
print(f"  Val X:   mean={X_val.mean():.3e}, std={X_val.std():.3e}")
print(f"  Test X:  mean={X_test.mean():.3e}, std={X_test.std():.3e}")

# Create datasets and dataloaders
train_dataset = EEGDataset(X_train, y_train)
val_dataset   = EEGDataset(X_val, y_val)
test_dataset  = EEGDataset(X_test, y_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset,   batch_size=32, shuffle=False)
test_loader  = torch.utils.data.DataLoader(test_dataset,  batch_size=32, shuffle=False)
# Out:
# Per-sample normalization complete
#   Train X: mean=-1.013e-22, std=1.426e-03
#   Val X:   mean=-5.672e-23, std=1.455e-03
#   Test X:  mean=1.085e-22, std=1.223e-03
#   Train X: mean=-1.013e-22, std=1.426e-03
#   Val X:   mean=-5.672e-23, std=1.455e-03
#   Test X:  mean=1.085e-22, std=1.223e-03

# %%
print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (47064, 19, 33, 7), Val shape: (10511, 19, 33, 7), Test shape: (12130, 19, 33, 7)

# %%
model = resnet18(weights=ResNet18_Weights.DEFAULT)
model = model.to(device)

# Freeze entire backbone initially
for param in model.parameters():
    param.requires_grad = False

# Replace first conv to accept 19 channels and make it trainable
model.conv1 = nn.Conv2d(
    in_channels=19,
    out_channels=64,
    kernel_size=(7, 7),
    stride=(2, 2),
    padding=(3, 3),
    bias=False
).to(device)
for param in model.conv1.parameters():
    param.requires_grad = True

# Replace final classifier and make it trainable
model.fc = nn.Linear(model.fc.in_features, 3).to(device)
for param in model.fc.parameters():
    param.requires_grad = True

print("Model initialized with:")
print("  - Frozen backbone (all layers)")
print("  - Trainable modified conv1 + final FC (classifier)")
# Optional: list trainable parameter names for verification
trainable = [name for name, p in model.named_parameters() if p.requires_grad]
print("Trainable parameters:", trainable)
# Out:
# Model initialized with:
#   - Frozen backbone (all layers)
#   - Trainable modified conv1 + final FC (classifier)
# Trainable parameters: ['conv1.weight', 'fc.weight', 'fc.bias']

# %%
# Calculate class weights based on training set distribution
unique_y_train, counts_y_train = np.unique(y_train, return_counts=True)
total_train = len(y_train)
class_weights_dict = {label: total_train / (count + 1e-8) for label, count in zip(unique_y_train, counts_y_train)}

print(f"\nClass distribution in training set:")
for label, count in zip(unique_y_train, counts_y_train):
    print(f"  Label {label}: {count} epochs ({100*count/total_train:.1f}%)")

# Create weight tensor: weights[i] is the weight for class i
weights_list = [class_weights_dict.get(i, 1.0) for i in range(3)]
weights = torch.tensor(weights_list, dtype=torch.float32)
print(f"\nClass weights: {weights.numpy()}")

# Use class weights to mitigate class imbalance
weights = weights.to(device)
criterion = nn.CrossEntropyLoss(weight=weights)
# Out:
# Class distribution in training set:
#   Label 0: 11373 epochs (24.2%)
#   Label 1: 19315 epochs (41.0%)
#   Label 2: 16376 epochs (34.8%)
#
# Class weights: [4.138222  2.4366555 2.873962 ]

# %%
num_epochs = 50
learning_rate = 1e-4
l2_lambda = 1e-5  # L2 regularization strength (weight decay)
# Only optimize parameters that require gradients (conv1 + fc)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate, weight_decay=l2_lambda)

# %%
# Initialize lists to track metrics per epoch
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# %%
best_val_acc = 0.0

for epoch in range(num_epochs):
    print(f"\nEpoch [{epoch+1}/{num_epochs}]")
    
    # ------- TRAIN -------
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()
        outputs = model(batch_x)

        loss = criterion(outputs, batch_y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        _, preds = outputs.max(1)
        correct += (preds == batch_y).sum().item()
        total += batch_y.size(0)

    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # ------- VALIDATION -------
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)

            val_loss += loss.item()
            _, preds = outputs.max(1)

            val_correct += (preds == batch_y).sum().item()
            val_total += batch_y.size(0)

    val_acc = val_correct / val_total
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), f"resnet_checkpoints/best_model_{best_val_acc}.pth")
        print("Saved new best model!")

    # ------- PRINT METRICS -------
    print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")
    print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
    print(f"Val Acc (smooth): {0.7*val_acc + 0.3*best_val_acc:.4f}")
# Out:
# Epoch [1/50]
# Saved new best model!
# Train Loss: 1447.3744, Train Acc: 0.5226
# Val Loss: 412.3262, Val Acc: 0.4202
# Val Acc (smooth): 0.4202
#
# Epoch [2/50]
# Saved new best model!
# Train Loss: 1447.3744, Train Acc: 0.5226
# Val Loss: 412.3262, Val Acc: 0.4202
# Val Acc (smooth): 0.4202
#
# Epoch [2/50]
# Saved new best model!
# Train Loss: 1081.6964, Train Acc: 0.6947
# Val Loss: 430.7035, Val Acc: 0.4651
# Val Acc (smooth): 0.4651
#
# Epoch [3/50]
# Saved new best model!
# Train Loss: 1081.6964, Train Acc: 0.6947
# Val Loss: 430.7035, Val Acc: 0.4651
# Val Acc (smooth): 0.4651
#
# Epoch [3/50]
# Train Loss: 891.8564, Train Acc: 0.7601
# Val Loss: 457.7027, Val Acc: 0.4592
# Val Acc (smooth): 0.4610
#
# Epoch [4/50]
# Train Loss: 891.8564, Train Acc: 0.7601
# Val Loss: 457.7027, Val Acc: 0.4592
# Val Acc (smooth): 0.4610
#
# Epoch [4/50]
# Train Loss: 777.1950, Train Acc: 0.7985
# Val Loss: 479.6959, Val Acc: 0.4614
# Val Acc (smooth): 0.4625
#
# Epoch [5/50]
# Train Loss: 777.1950, Train Acc: 0.7985
# Val Loss: 479.6959, Val Acc: 0.4614
# Val Acc (smooth): 0.4625
#
# Epoch [5/50]
# Train Loss: 708.4799, Train Acc: 0.8173
# Val Loss: 466.4156, Val Acc: 0.4483
# Val Acc (smooth): 0.4533
#
# Epoch [6/50]
# Train Loss: 708.4799, Train Acc: 0.8173
# Val Loss: 466.4156, Val Acc: 0.4483
# Val Acc (smooth): 0.4533
#
# Epoch [6/50]
# Train Loss: 651.9421, Train Acc: 0.8345
# Val Loss: 524.2016, Val Acc: 0.3852
# Val Acc (smooth): 0.4092
#
# Epoch [7/50]
# Train Loss: 651.9421, Train Acc: 0.8345
# Val Loss: 524.2016, Val Acc: 0.3852
# Val Acc (smooth): 0.4092
#
# Epoch [7/50]
# Train Loss: 613.4576, Train Acc: 0.8447
# Val Loss: 475.7730, Val Acc: 0.4154
# Val Acc (smooth): 0.4303
#
# Epoch [8/50]
# Train Loss: 613.4576, Train Acc: 0.8447
# Val Loss: 475.7730, Val Acc: 0.4154
# Val Acc (smooth): 0.4303
#
# Epoch [8/50]
# Saved new best model!
# Train Loss: 577.0166, Train Acc: 0.8551
# Val Loss: 474.7100, Val Acc: 0.4705
# Val Acc (smooth): 0.4705
#
# Epoch [9/50]
# Saved new best model!
# Train Loss: 577.0166, Train Acc: 0.8551
# Val Loss: 474.7100, Val Acc: 0.4705
# Val Acc (smooth): 0.4705
#
# Epoch [9/50]
# Saved new best model!
# Train Loss: 561.5644, Train Acc: 0.8574
# Val Loss: 472.7020, Val Acc: 0.5272
# Val Acc (smooth): 0.5272
#
# Epoch [10/50]
# Saved new best model!
# Train Loss: 561.5644, Train Acc: 0.8574
# Val Loss: 472.7020, Val Acc: 0.5272
# Val Acc (smooth): 0.5272
#
# Epoch [10/50]
# Train Loss: 534.4639, Train Acc: 0.8664
# Val Loss: 539.7116, Val Acc: 0.5229
# Val Acc (smooth): 0.5242
#
# Epoch [11/50]
# Train Loss: 534.4639, Train Acc: 0.8664
# Val Loss: 539.7116, Val Acc: 0.5229
# Val Acc (smooth): 0.5242
#
# Epoch [11/50]
# Train Loss: 508.3547, Train Acc: 0.8735
# Val Loss: 503.7613, Val Acc: 0.4919
# Val Acc (smooth): 0.5025
#
# Epoch [12/50]
# Train Loss: 508.3547, Train Acc: 0.8735
# Val Loss: 503.7613, Val Acc: 0.4919
# Val Acc (smooth): 0.5025
#
# Epoch [12/50]
# Train Loss: 488.9561, Train Acc: 0.8798
# Val Loss: 542.8685, Val Acc: 0.5012
# Val Acc (smooth): 0.5090
#
# Epoch [13/50]
# Train Loss: 488.9561, Train Acc: 0.8798
# Val Loss: 542.8685, Val Acc: 0.5012
# Val Acc (smooth): 0.5090
#
# Epoch [13/50]
# Train Loss: 484.3956, Train Acc: 0.8790
# Val Loss: 546.6118, Val Acc: 0.5122
# Val Acc (smooth): 0.5167
#
# Epoch [14/50]
# Train Loss: 484.3956, Train Acc: 0.8790
# Val Loss: 546.6118, Val Acc: 0.5122
# Val Acc (smooth): 0.5167
#
# Epoch [14/50]
# Train Loss: 467.1316, Train Acc: 0.8843
# Val Loss: 552.4998, Val Acc: 0.4990
# Val Acc (smooth): 0.5074
#
# Epoch [15/50]
# Train Loss: 467.1316, Train Acc: 0.8843
# Val Loss: 552.4998, Val Acc: 0.4990
# Val Acc (smooth): 0.5074
#
# Epoch [15/50]
# Train Loss: 451.4118, Train Acc: 0.8878
# Val Loss: 545.7716, Val Acc: 0.4940
# Val Acc (smooth): 0.5039
#
# Epoch [16/50]
# Train Loss: 451.4118, Train Acc: 0.8878
# Val Loss: 545.7716, Val Acc: 0.4940
# Val Acc (smooth): 0.5039
#
# Epoch [16/50]
# Saved new best model!
# Train Loss: 441.0624, Train Acc: 0.8916
# Val Loss: 519.8459, Val Acc: 0.5441
# Val Acc (smooth): 0.5441
#
# Epoch [17/50]
# Saved new best model!
# Train Loss: 441.0624, Train Acc: 0.8916
# Val Loss: 519.8459, Val Acc: 0.5441
# Val Acc (smooth): 0.5441
#
# Epoch [17/50]
# Train Loss: 428.8507, Train Acc: 0.8960
# Val Loss: 537.7501, Val Acc: 0.5250
# Val Acc (smooth): 0.5307
#
# Epoch [18/50]
# Train Loss: 428.8507, Train Acc: 0.8960
# Val Loss: 537.7501, Val Acc: 0.5250
# Val Acc (smooth): 0.5307
#
# Epoch [18/50]
# Saved new best model!
# Train Loss: 422.4063, Train Acc: 0.8985
# Val Loss: 522.4611, Val Acc: 0.5483
# Val Acc (smooth): 0.5483
#
# Epoch [19/50]
# Saved new best model!
# Train Loss: 422.4063, Train Acc: 0.8985
# Val Loss: 522.4611, Val Acc: 0.5483
# Val Acc (smooth): 0.5483
#
# Epoch [19/50]
# Train Loss: 416.9922, Train Acc: 0.8968
# Val Loss: 528.8863, Val Acc: 0.5169
# Val Acc (smooth): 0.5263
#
# Epoch [20/50]
# Train Loss: 416.9922, Train Acc: 0.8968
# Val Loss: 528.8863, Val Acc: 0.5169
# Val Acc (smooth): 0.5263
#
# Epoch [20/50]
# Train Loss: 404.2993, Train Acc: 0.9006
# Val Loss: 626.8741, Val Acc: 0.5215
# Val Acc (smooth): 0.5295
#
# Epoch [21/50]
# Train Loss: 404.2993, Train Acc: 0.9006
# Val Loss: 626.8741, Val Acc: 0.5215
# Val Acc (smooth): 0.5295
#
# Epoch [21/50]
# Train Loss: 392.4859, Train Acc: 0.9050
# Val Loss: 560.6466, Val Acc: 0.5165
# Val Acc (smooth): 0.5260
#
# Epoch [22/50]
# Train Loss: 392.4859, Train Acc: 0.9050
# Val Loss: 560.6466, Val Acc: 0.5165
# Val Acc (smooth): 0.5260
#
# Epoch [22/50]
# Train Loss: 382.2947, Train Acc: 0.9067
# Val Loss: 552.3305, Val Acc: 0.5446
# Val Acc (smooth): 0.5457
#
# Epoch [23/50]
# Train Loss: 382.2947, Train Acc: 0.9067
# Val Loss: 552.3305, Val Acc: 0.5446
# Val Acc (smooth): 0.5457
#
# Epoch [23/50]
# Saved new best model!
# Train Loss: 380.6791, Train Acc: 0.9084
# Val Loss: 558.3455, Val Acc: 0.5588
# Val Acc (smooth): 0.5588
#
# Epoch [24/50]
# Saved new best model!
# Train Loss: 380.6791, Train Acc: 0.9084
# Val Loss: 558.3455, Val Acc: 0.5588
# Val Acc (smooth): 0.5588
#
# Epoch [24/50]
# Train Loss: 372.0187, Train Acc: 0.9103
# Val Loss: 645.8116, Val Acc: 0.5476
# Val Acc (smooth): 0.5510
#
# Epoch [25/50]
# Train Loss: 372.0187, Train Acc: 0.9103
# Val Loss: 645.8116, Val Acc: 0.5476
# Val Acc (smooth): 0.5510
#
# Epoch [25/50]
# Train Loss: 360.2618, Train Acc: 0.9121
# Val Loss: 620.3784, Val Acc: 0.5151
# Val Acc (smooth): 0.5282
#
# Epoch [26/50]
# Train Loss: 360.2618, Train Acc: 0.9121
# Val Loss: 620.3784, Val Acc: 0.5151
# Val Acc (smooth): 0.5282
#
# Epoch [26/50]
# Train Loss: 369.0943, Train Acc: 0.9114
# Val Loss: 587.6819, Val Acc: 0.5480
# Val Acc (smooth): 0.5513
#
# Epoch [27/50]
# Train Loss: 369.0943, Train Acc: 0.9114
# Val Loss: 587.6819, Val Acc: 0.5480
# Val Acc (smooth): 0.5513
#
# Epoch [27/50]
# Train Loss: 359.2107, Train Acc: 0.9121
# Val Loss: 554.7590, Val Acc: 0.5243
# Val Acc (smooth): 0.5347
#
# Epoch [28/50]
# Train Loss: 359.2107, Train Acc: 0.9121
# Val Loss: 554.7590, Val Acc: 0.5243
# Val Acc (smooth): 0.5347
#
# Epoch [28/50]
# Train Loss: 344.3170, Train Acc: 0.9175
# Val Loss: 579.3849, Val Acc: 0.5549
# Val Acc (smooth): 0.5561
#
# Epoch [29/50]
# Train Loss: 344.3170, Train Acc: 0.9175
# Val Loss: 579.3849, Val Acc: 0.5549
# Val Acc (smooth): 0.5561
#
# Epoch [29/50]
# Train Loss: 347.3011, Train Acc: 0.9162
# Val Loss: 594.1203, Val Acc: 0.5376
# Val Acc (smooth): 0.5440
#
# Epoch [30/50]
# Train Loss: 347.3011, Train Acc: 0.9162
# Val Loss: 594.1203, Val Acc: 0.5376
# Val Acc (smooth): 0.5440
#
# Epoch [30/50]
# Train Loss: 337.2369, Train Acc: 0.9174
# Val Loss: 603.7383, Val Acc: 0.5417
# Val Acc (smooth): 0.5469
#
# Epoch [31/50]
# Train Loss: 337.2369, Train Acc: 0.9174
# Val Loss: 603.7383, Val Acc: 0.5417
# Val Acc (smooth): 0.5469
#
# Epoch [31/50]
# Train Loss: 332.9603, Train Acc: 0.9206
# Val Loss: 636.3831, Val Acc: 0.5251
# Val Acc (smooth): 0.5352
#
# Epoch [32/50]
# Train Loss: 332.9603, Train Acc: 0.9206
# Val Loss: 636.3831, Val Acc: 0.5251
# Val Acc (smooth): 0.5352
#
# Epoch [32/50]
# Train Loss: 330.5084, Train Acc: 0.9193
# Val Loss: 705.7817, Val Acc: 0.5320
# Val Acc (smooth): 0.5401
#
# Epoch [33/50]
# Train Loss: 330.5084, Train Acc: 0.9193
# Val Loss: 705.7817, Val Acc: 0.5320
# Val Acc (smooth): 0.5401
#
# Epoch [33/50]
# Train Loss: 323.5205, Train Acc: 0.9206
# Val Loss: 643.3060, Val Acc: 0.5409
# Val Acc (smooth): 0.5463
#
# Epoch [34/50]
# Train Loss: 323.5205, Train Acc: 0.9206
# Val Loss: 643.3060, Val Acc: 0.5409
# Val Acc (smooth): 0.5463
#
# Epoch [34/50]
# Train Loss: 320.3527, Train Acc: 0.9222
# Val Loss: 746.5913, Val Acc: 0.5390
# Val Acc (smooth): 0.5449
#
# Epoch [35/50]
# Train Loss: 320.3527, Train Acc: 0.9222
# Val Loss: 746.5913, Val Acc: 0.5390
# Val Acc (smooth): 0.5449
#
# Epoch [35/50]
# Train Loss: 320.3185, Train Acc: 0.9233
# Val Loss: 594.1145, Val Acc: 0.5215
# Val Acc (smooth): 0.5327
#
# Epoch [36/50]
# Train Loss: 320.3185, Train Acc: 0.9233
# Val Loss: 594.1145, Val Acc: 0.5215
# Val Acc (smooth): 0.5327
#
# Epoch [36/50]
# Train Loss: 317.5003, Train Acc: 0.9229
# Val Loss: 592.4774, Val Acc: 0.5312
# Val Acc (smooth): 0.5395
#
# Epoch [37/50]
# Train Loss: 317.5003, Train Acc: 0.9229
# Val Loss: 592.4774, Val Acc: 0.5312
# Val Acc (smooth): 0.5395
#
# Epoch [37/50]
# Train Loss: 309.8163, Train Acc: 0.9256
# Val Loss: 592.4857, Val Acc: 0.4922
# Val Acc (smooth): 0.5122
#
# Epoch [38/50]
# Train Loss: 309.8163, Train Acc: 0.9256
# Val Loss: 592.4857, Val Acc: 0.4922
# Val Acc (smooth): 0.5122
#
# Epoch [38/50]
# Train Loss: 303.6674, Train Acc: 0.9270
# Val Loss: 648.5189, Val Acc: 0.5250
# Val Acc (smooth): 0.5351
#
# Epoch [39/50]
# Train Loss: 303.6674, Train Acc: 0.9270
# Val Loss: 648.5189, Val Acc: 0.5250
# Val Acc (smooth): 0.5351
#
# Epoch [39/50]
# Train Loss: 305.1493, Train Acc: 0.9265
# Val Loss: 642.2755, Val Acc: 0.5453
# Val Acc (smooth): 0.5494
#
# Epoch [40/50]
# Train Loss: 305.1493, Train Acc: 0.9265
# Val Loss: 642.2755, Val Acc: 0.5453
# Val Acc (smooth): 0.5494
#
# Epoch [40/50]
# Train Loss: 302.9784, Train Acc: 0.9280
# Val Loss: 683.7181, Val Acc: 0.5374
# Val Acc (smooth): 0.5439
#
# Epoch [41/50]
# Train Loss: 302.9784, Train Acc: 0.9280
# Val Loss: 683.7181, Val Acc: 0.5374
# Val Acc (smooth): 0.5439
#
# Epoch [41/50]
# Train Loss: 297.4375, Train Acc: 0.9286
# Val Loss: 690.8883, Val Acc: 0.5337
# Val Acc (smooth): 0.5413
#
# Epoch [42/50]
# Train Loss: 297.4375, Train Acc: 0.9286
# Val Loss: 690.8883, Val Acc: 0.5337
# Val Acc (smooth): 0.5413
#
# Epoch [42/50]
# Train Loss: 307.6499, Train Acc: 0.9267
# Val Loss: 639.6330, Val Acc: 0.5472
# Val Acc (smooth): 0.5507
#
# Epoch [43/50]
# Train Loss: 307.6499, Train Acc: 0.9267
# Val Loss: 639.6330, Val Acc: 0.5472
# Val Acc (smooth): 0.5507
#
# Epoch [43/50]
# Train Loss: 298.0848, Train Acc: 0.9297
# Val Loss: 655.2159, Val Acc: 0.5226
# Val Acc (smooth): 0.5335
#
# Epoch [44/50]
# Train Loss: 298.0848, Train Acc: 0.9297
# Val Loss: 655.2159, Val Acc: 0.5226
# Val Acc (smooth): 0.5335
#
# Epoch [44/50]
# Saved new best model!
# Train Loss: 282.0482, Train Acc: 0.9314
# Val Loss: 725.3290, Val Acc: 0.5622
# Val Acc (smooth): 0.5622
#
# Epoch [45/50]
# Saved new best model!
# Train Loss: 282.0482, Train Acc: 0.9314
# Val Loss: 725.3290, Val Acc: 0.5622
# Val Acc (smooth): 0.5622
#
# Epoch [45/50]
# Train Loss: 287.1679, Train Acc: 0.9310
# Val Loss: 833.0201, Val Acc: 0.5409
# Val Acc (smooth): 0.5473
#
# Epoch [46/50]
# Train Loss: 287.1679, Train Acc: 0.9310
# Val Loss: 833.0201, Val Acc: 0.5409
# Val Acc (smooth): 0.5473
#
# Epoch [46/50]
# Train Loss: 279.9960, Train Acc: 0.9315
# Val Loss: 828.6083, Val Acc: 0.5238
# Val Acc (smooth): 0.5353
#
# Epoch [47/50]
# Train Loss: 279.9960, Train Acc: 0.9315
# Val Loss: 828.6083, Val Acc: 0.5238
# Val Acc (smooth): 0.5353
#
# Epoch [47/50]
# Train Loss: 286.1455, Train Acc: 0.9308
# Val Loss: 801.5309, Val Acc: 0.5186
# Val Acc (smooth): 0.5317
#
# Epoch [48/50]
# Train Loss: 286.1455, Train Acc: 0.9308
# Val Loss: 801.5309, Val Acc: 0.5186
# Val Acc (smooth): 0.5317
#
# Epoch [48/50]
# Train Loss: 289.4395, Train Acc: 0.9318
# Val Loss: 745.3399, Val Acc: 0.5253
# Val Acc (smooth): 0.5363
#
# Epoch [49/50]
# Train Loss: 289.4395, Train Acc: 0.9318
# Val Loss: 745.3399, Val Acc: 0.5253
# Val Acc (smooth): 0.5363
#
# Epoch [49/50]
# Train Loss: 278.2894, Train Acc: 0.9332
# Val Loss: 849.9994, Val Acc: 0.5351
# Val Acc (smooth): 0.5432
#
# Epoch [50/50]
# Train Loss: 278.2894, Train Acc: 0.9332
# Val Loss: 849.9994, Val Acc: 0.5351
# Val Acc (smooth): 0.5432
#
# Epoch [50/50]
# Train Loss: 273.2091, Train Acc: 0.9353
# Val Loss: 704.1300, Val Acc: 0.5300
# Val Acc (smooth): 0.5397
# Train Loss: 273.2091, Train Acc: 0.9353
# Val Loss: 704.1300, Val Acc: 0.5300
# Val Acc (smooth): 0.5397

# %%
# Plot training vs validation accuracy to visualize overfitting
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
epochs_range = range(1, len(train_accs) + 1)
plt.plot(epochs_range, train_accs, 'b-', label='Train Accuracy', linewidth=2)
plt.plot(epochs_range, val_accs, 'r-', label='Val Accuracy', linewidth=2)
plt.fill_between(epochs_range, train_accs, val_accs, alpha=0.2, color='orange', label='Overfitting Gap')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_losses, 'b-', label='Train Loss', linewidth=2)
plt.plot(epochs_range, val_losses, 'r-', label='Val Loss', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nOverfitting Analysis:")
print(f"  Final Train Acc: {train_accs[-1]:.4f}")
print(f"  Final Val Acc:   {val_accs[-1]:.4f}")
print(f"  Overfitting Gap: {train_accs[-1] - val_accs[-1]:.4f}")
# Out:
# Overfitting Analysis:
#   Final Train Acc: 0.9353
#   Final Val Acc:   0.5300
#   Overfitting Gap: 0.4053

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Accuracy: 50.80%

# %%
# Make sure model is in evaluation mode
model.eval()

all_preds = []
all_labels = []

# Disable gradients for evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        all_preds.append(predicted.cpu().numpy())
        all_labels.append(labels.cpu().numpy())

# Flatten lists
all_preds = np.concatenate(all_preds)
all_labels = np.concatenate(all_labels)

# --- Accuracy ---
accuracy = (all_preds == all_labels).mean()
print(f"Test Accuracy: {accuracy*100:.2f}%\n")

# --- Confusion Matrix ---
# Labels encoding: 0=Healthy, 1=Alzheimer (AD), 2=FTD
class_names = ["Healthy", "AD", "FTD"]
cm = confusion_matrix(all_labels, all_preds)
print("Confusion Matrix:\n", cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# --- Precision, Recall, F1 ---
report = classification_report(all_labels, all_preds, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# Test Accuracy: 50.80%
#
# Confusion Matrix:
#  [[ 833  718  872]
#  [1125 2769 1680]
#  [ 860  713 2560]]
# Classification Report:
#                precision    recall  f1-score   support
#
#      Healthy       0.30      0.34      0.32      2423
#           AD       0.66      0.50      0.57      5574
#          FTD       0.50      0.62      0.55      4133
#
#     accuracy                           0.51     12130
#    macro avg       0.49      0.49      0.48     12130
# weighted avg       0.53      0.51      0.51     12130
