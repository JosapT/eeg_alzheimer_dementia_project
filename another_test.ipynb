# %%
import torch
print(torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#       3 print("MPS available:", torch.backends.mps.is_available())
#
# File /opt/anaconda3/envs/cs_184a_final/lib/python3.10/site-packages/torch/__init__.py:409
#     407     if USE_GLOBAL_DEPS:
#     408         _load_global_deps()
# --> 409     from torch._C import *  # noqa: F403
#     412 class SymInt:
#     413     """
#     414     Like an int (including magic methods), but redirects all operations on the
#     415     wrapped node. This is used in particular to symbolically record operations
#     416     in the symbolic shape workflow.
#     417     """
#
# ImportError: dlopen(/opt/anaconda3/envs/cs_184a_final/lib/python3.10/site-packages/torch/_C.cpython-310-darwin.so, 0x0002): Symbol not found: __ZN2at3mps14getMPSProfilerEv
#   Referenced from: <87990CDC-8638-3D8A-A1BC-5D5F1AFAC55E> /opt/anaconda3/envs/cs_184a_final/lib/libtorch_python.dylib
#   Expected in:     <EF517B96-4CE4-357A-A9AB-03F243F0861C> /opt/anaconda3/envs/cs_184a_final/lib/libtorch_cpu.dylib
